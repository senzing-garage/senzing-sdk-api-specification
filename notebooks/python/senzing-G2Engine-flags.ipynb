# %% [markdown]
# ## processWithResponse
#
# These are the control flags applicable to `processWithResponse()`:
#
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## getRecord
#
# These are the control flags that are applicable to `getRecord()`:
#
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA

# %% [markdown]
# ## getEntityByRecordID
#
# These are the control flags that are applicable to `getEntityByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## getEntityByEntityID
#
# These are the control flags that are applicable to `getEntityByEntityID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## getVirtualEntityByRecordID
#
# These are the control flags that are applicable to `getVirtualEntityByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## searchByAttributes
#
# These are the control flags applicable to `searchByAttributes()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_INCLUDE_FEATURE_SCORES
# - G2_SEARCH_INCLUDE_STATS

# %% [markdown]
# ## findPathByEntityID
#
# These are the control flags that are applicable to `findPathByEntityID()`:
#
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findPathByRecordID
#
# These are the control flags that are applicable to `findPathByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findPathExcludingByEntityID
#
# These are the control flags that are applicable to `findPathExcludingByEntityID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findPathExcludingByRecordID
#
# These are the control flags that are applicable to `findPathExcludingByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findPathIncludingSourceByEntityID
#
# These are the control flags that are applicable to `findPathIncludingSourceByEntityID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findPathIncludingSourceByRecordID
#
# These are the control flags that are applicable to `findPathIncludingSouceByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_FIND_PATH_PREFER_EXCLUDE

# %% [markdown]
# ## findNetworkByEntityID
#
# These are the control flags that are applicable to `findNetworkByEntityID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## findNetworkByRecordID
#
# These are the control flags that are applicable to `findNetworkByRecordID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## whyEntities
#
# These are the control flags that are applicable to `whyEntities()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_INCLUDE_FEATURE_SCORES

# %% [markdown]
# ## whyRecords
#
# These are the control flags that are applicable to `whyRecords()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_INCLUDE_FEATURE_SCORES

# %% [markdown]
# ## whyEntityByEntityID
#
# These are the control flags that are applicable to `whyEntityByEntityID()`:
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_INCLUDE_FEATURE_SCORES

# %% [markdown]
# ## whyEntityByRecordID
#
# These are the control flags that are applicable to `whyEntityByRecordID()`;
#
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS
# - G2_INCLUDE_FEATURE_SCORES

# %% [markdown]
# ## exportJSONEntityReport
#
# These are the control flags that are applicable to `exportJSONEntityReport()`:
#
# - G2_EXPORT_INCLUDE_RESOLVED
# - G2_EXPORT_INCLUDE_POSSIBLY_SAME
# - G2_EXPORT_INCLUDE_POSSIBLY_RELATED
# - G2_EXPORT_INCLUDE_NAME_ONLY
# - G2_EXPORT_INCLUDE_DISCLOSED
# - G2_EXPORT_INCLUDE_SINGLETONS
# - G2_ENTITY_INCLUDE_POSSIBLY_SAME_RELATIONS
# - G2_ENTITY_INCLUDE_POSSIBLY_RELATED_RELATIONS
# - G2_ENTITY_INCLUDE_NAME_ONLY_RELATIONS
# - G2_ENTITY_INCLUDE_DISCLOSED_RELATIONS
# - G2_ENTITY_INCLUDE_ALL_FEATURES
# - G2_ENTITY_INCLUDE_REPRESENTATIVE_FEATURES
# - G2_ENTITY_INCLUDE_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RECORD_DATA
# - G2_ENTITY_INCLUDE_RECORD_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RECORD_JSON_DATA
# - G2_ENTITY_INCLUDE_RECORD_FORMATTED_DATA
# - G2_ENTITY_INCLUDE_RECORD_FEATURE_IDS
# - G2_ENTITY_INCLUDE_RELATED_ENTITY_NAME
# - G2_ENTITY_INCLUDE_RELATED_MATCHING_INFO
# - G2_ENTITY_INCLUDE_RELATED_RECORD_SUMMARY
# - G2_ENTITY_INCLUDE_RELATED_RECORD_DATA
# - G2_ENTITY_OPTION_INCLUDE_INTERNAL_FEATURES
# - G2_ENTITY_OPTION_INCLUDE_FEATURE_STATS

# %% [markdown]
# ## exportCSVEntityReport
#
# These are the control flags that are applicable to `exportCSVEntityReport()`:
#
# - G2_EXPORT_INCLUDE_RESOLVED
# - G2_EXPORT_INCLUDE_POSSIBLY_SAME
# - G2_EXPORT_INCLUDE_POSSIBLY_RELATED
# - G2_EXPORT_INCLUDE_NAME_ONLY
# - G2_EXPORT_INCLUDE_DISCLOSED
# - G2_EXPORT_INCLUDE_SINGLETONS
